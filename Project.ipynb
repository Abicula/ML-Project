# %% [markdown]
# ## Important notes:
#
# surface level Ozone is reported in parts per million

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from scipy.signal import filtfilt
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader 
from torchsummary import summary

# %%
device = 'cpu'
if torch.cuda.device_count() > 0 and torch.cuda.is_available():
    print("Cuda installed! Running on GPU!")
    device = 'cuda'
else:
    print("No GPU available!")
print(f'Device: {device}')
# Out:
# Cuda installed! Running on GPU!
# Device: cuda

# %%
# Importing the main meteorological data

traindata = pd.read_csv('./Data/pr_temp_wind_2018_2022_Bos.csv', sep=',')

# %%
# Importing all other feature data

traindata_SO2_2018 = pd.read_csv('./Data/SO2_daily_2018.csv', sep=',')
traindata_SO2_2019 = pd.read_csv('./Data/SO2_daily_2019.csv', sep=',')
traindata_SO2_2020 = pd.read_csv('./Data/SO2_daily_2020.csv', sep=',')
traindata_SO2_2021 = pd.read_csv('./Data/SO2_daily_2021.csv', sep=',')

traindata_CO_2018 = pd.read_csv('./Data/CO_daily_2018.csv', sep=',')
traindata_CO_2019 = pd.read_csv('./Data/CO_daily_2019.csv', sep=',')
traindata_CO_2020 = pd.read_csv('./Data/CO_daily_2020.csv', sep=',')
traindata_CO_2021 = pd.read_csv('./Data/CO_daily_2021.csv', sep=',')

traindata_NO2_2018 = pd.read_csv('./Data/NO2_daily_2018.csv', sep=',')
traindata_NO2_2019 = pd.read_csv('./Data/NO2_daily_2019.csv', sep=',')
traindata_NO2_2020 = pd.read_csv('./Data/NO2_daily_2020.csv', sep=',')
traindata_NO2_2021 = pd.read_csv('./Data/NO2_daily_2021.csv', sep=',')
# Out:
# /tmp/ipykernel_91/3207368089.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_SO2_2018 = pd.read_csv('./Data/SO2_daily_2018.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_SO2_2019 = pd.read_csv('./Data/SO2_daily_2019.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:5: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_SO2_2020 = pd.read_csv('./Data/SO2_daily_2020.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_SO2_2021 = pd.read_csv('./Data/SO2_daily_2021.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_CO_2018 = pd.read_csv('./Data/CO_daily_2018.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:9: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_CO_2019 = pd.read_csv('./Data/CO_daily_2019.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:10: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_CO_2020 = pd.read_csv('./Data/CO_daily_2020.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:11: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_CO_2021 = pd.read_csv('./Data/CO_daily_2021.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:14: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_NO2_2019 = pd.read_csv('./Data/NO2_daily_2019.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:15: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_NO2_2020 = pd.read_csv('./Data/NO2_daily_2020.csv', sep=',')
# /tmp/ipykernel_91/3207368089.py:16: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata_NO2_2021 = pd.read_csv('./Data/NO2_daily_2021.csv', sep=',')

# %%
traindata = traindata.dropna()

# %%
traindata
# Out:
#           STATION                                       NAME  LATITUDE
# 0     USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057  \
# 1     USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 2     USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 3     USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 4     USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# ...           ...                                        ...       ...
# 1821  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 1822  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 1823  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 1824  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
# 1825  USW00014739  BOSTON LOGAN INTERNATIONAL AIRPORT, MA US  42.36057
#
#       LONGITUDE  ELEVATION        DATE  AWND  PRCP  TAVG  TMAX  TMIN
# 0     -71.00975        3.2    1/1/2018   7.3   0.0 -14.7 -10.5 -17.7
# 1     -71.00975        3.2    1/2/2018   5.7   0.0 -12.3  -7.1 -15.5
# 2     -71.00975        3.2    1/3/2018   4.2   0.0  -6.2  -1.6  -8.8
# 3     -71.00975        3.2    1/4/2018  10.1  34.3  -3.6  -1.0  -5.5
# 4     -71.00975        3.2    1/5/2018  11.1   0.0  -7.8  -4.3 -14.3
# ...         ...        ...         ...   ...   ...   ...   ...   ...
# 1821  -71.00975        3.2  12/27/2022   4.5   0.0  -0.7   2.2  -2.1
# 1822  -71.00975        3.2  12/28/2022   3.8   0.0   0.2   6.1  -4.3
# 1823  -71.00975        3.2  12/29/2022   3.4   0.0   4.9  12.2   0.0
# 1824  -71.00975        3.2  12/30/2022   3.9   0.0   9.1  17.2   3.9
# 1825  -71.00975        3.2  12/31/2022   4.1   8.9   9.6  12.2   6.7
#
# [1826 rows x 11 columns]

# %%
# Importing target data
target_data_2021 = pd.read_csv('./Data/ozone_daily_2021.csv', sep=',')
target_data_2020 = pd.read_csv('./Data/ozone_daily_2020.csv', sep=',')
target_data_2019 = pd.read_csv('./Data/ozone_daily_2019.csv', sep=',')
target_data_2018 = pd.read_csv('./Data/ozone_daily_2018.csv', sep=',')
# Out:
# /tmp/ipykernel_91/2871470904.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   target_data_2021 = pd.read_csv('./Data/ozone_daily_2021.csv', sep=',')
# /tmp/ipykernel_91/2871470904.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   target_data_2020 = pd.read_csv('./Data/ozone_daily_2020.csv', sep=',')
# /tmp/ipykernel_91/2871470904.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   target_data_2019 = pd.read_csv('./Data/ozone_daily_2019.csv', sep=',')
# /tmp/ipykernel_91/2871470904.py:5: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   target_data_2018 = pd.read_csv('./Data/ozone_daily_2018.csv', sep=',')

# %%
#mask = target_data["City Name"]

# %%
# for i in range(len(mask)):
#     if mask[i] != "Lynn":
#         mask = mask.drop([i])

# %%
# Masks
target_mask = target_data_2018["City Name"] == "Lynn"
SO2_mask = traindata_SO2_2018["City Name"] == "Boston"
NO2_mask = traindata_NO2_2018["City Name"] == "Lynn"
#CO_mask = traindata_CO_2018["City Name"] == "Boston"

# %%
target_data_Lynn_2021 = target_data_2021.loc[target_mask]
target_data_Lynn_2020 = target_data_2020.loc[target_mask]
target_data_Lynn_2019 = target_data_2019.loc[target_mask]
target_data_Lynn_2018 = target_data_2018.loc[target_mask]

# %%
target_data_Lynn_2018
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 198887          25            9      2006           44201    1  42.474642  \
# 198888          25            9      2006           44201    1  42.474642
# 198889          25            9      2006           44201    1  42.474642
# 198890          25            9      2006           44201    1  42.474642
# 198891          25            9      2006           44201    1  42.474642
# ...            ...          ...       ...             ...  ...        ...
# 199246          25            9      2006           44201    1  42.474642
# 199247          25            9      2006           44201    1  42.474642
# 199248          25            9      2006           44201    1  42.474642
# 199249          25            9      2006           44201    1  42.474642
# 199250          25            9      2006           44201    1  42.474642
#
#         Longitude  Datum Parameter Name          Sample Duration  ... AQI
# 198887 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  37  \
# 198888 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  13
# 198889 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  36
# 198890 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  34
# 198891 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  36
# ...           ...    ...            ...                      ...  ...  ..
# 199246 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31
# 199247 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  25
# 199248 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31
# 199249 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  27
# 199250 -70.970816  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  27
#
#        Method Code Method Name             Local Site Name       Address
# 198887         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND  \
# 198888         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 198889         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 198890         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 198891         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# ...            ...         ...                         ...           ...
# 199246         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 199247         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 199248         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 199249         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
# 199250         NaN          -   LYNN WATER TREATMENT PLANT  390 PARKLAND
#
#            State Name  County Name  City Name                       CBSA Name
# 198887  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH  \
# 198888  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 198889  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 198890  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 198891  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# ...               ...          ...        ...                             ...
# 199246  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 199247  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 199248  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 199249  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
# 199250  Massachusetts        Essex       Lynn  Boston-Cambridge-Newton, MA-NH
#
#         Date of Last Change
# 198887           2021-11-04
# 198888           2021-11-04
# 198889           2021-11-04
# 198890           2021-11-04
# 198891           2021-11-04
# ...                     ...
# 199246           2021-11-04
# 199247           2021-11-04
# 199248           2021-11-04
# 199249           2021-11-04
# 199250           2021-11-04
#
# [364 rows x 29 columns]

# %%
traindata_SO2_Lynn_2021 = traindata_SO2_2021.loc[traindata_SO2_2021["City Name"] == "Boston"]
traindata_SO2_Lynn_2020 = traindata_SO2_2020.loc[traindata_SO2_2020["City Name"] == "Boston"]
traindata_SO2_Lynn_2019 = traindata_SO2_2019.loc[traindata_SO2_2019["City Name"] == "Boston"]
traindata_SO2_Lynn_2018 = traindata_SO2_2018.loc[SO2_mask]

traindata_SO2_Lynn_2021 = traindata_SO2_Lynn_2021.loc[traindata_SO2_Lynn_2021["Sample Duration"] == "1 HOUR"]
traindata_SO2_Lynn_2020 = traindata_SO2_Lynn_2020.loc[traindata_SO2_Lynn_2020["Sample Duration"] == "1 HOUR"]
traindata_SO2_Lynn_2019 = traindata_SO2_Lynn_2019.loc[traindata_SO2_Lynn_2019["Sample Duration"] == "1 HOUR"]
traindata_SO2_Lynn_2018 = traindata_SO2_Lynn_2018.loc[traindata_SO2_Lynn_2018["Sample Duration"] == "1 HOUR"]

traindata_SO2_Lynn_2021 = traindata_SO2_Lynn_2021.loc[traindata_SO2_Lynn_2021["Address"] == "KENMORE SQ"]
traindata_SO2_Lynn_2020 = traindata_SO2_Lynn_2020.loc[traindata_SO2_Lynn_2020["Address"] == "KENMORE SQ"]
traindata_SO2_Lynn_2019 = traindata_SO2_Lynn_2019.loc[traindata_SO2_Lynn_2019["Address"] == "KENMORE SQ"]
traindata_SO2_Lynn_2018 = traindata_SO2_Lynn_2018.loc[traindata_SO2_Lynn_2018["Address"] == "KENMORE SQ"]

# %%
traindata_SO2_Lynn_2018
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 129074          25           25         2           42401    1  42.348873  \
# 129075          25           25         2           42401    1  42.348873
# 129076          25           25         2           42401    1  42.348873
# 129077          25           25         2           42401    1  42.348873
# 129078          25           25         2           42401    1  42.348873
# ...            ...          ...       ...             ...  ...        ...
# 129431          25           25         2           42401    1  42.348873
# 129432          25           25         2           42401    1  42.348873
# 129433          25           25         2           42401    1  42.348873
# 129434          25           25         2           42401    1  42.348873
# 129435          25           25         2           42401    1  42.348873
#
#         Longitude  Datum  Parameter Name Sample Duration  ...  AQI
# 129074 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  1.0  \
# 129075 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  1.0
# 129076 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  3.0
# 129077 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  4.0
# 129078 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  1.0
# ...           ...    ...             ...             ...  ...  ...
# 129431 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  0.0
# 129432 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  0.0
# 129433 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  0.0
# 129434 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  0.0
# 129435 -71.097163  WGS84  Sulfur dioxide          1 HOUR  ...  0.0
#
#        Method Code                                        Method Name
# 129074       600.0  Instrumental - Ultraviolet Fluorescence API 10...  \
# 129075       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129076       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129077       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129078       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# ...            ...                                                ...
# 129431       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129432       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129433       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129434       600.0  Instrumental - Ultraviolet Fluorescence API 10...
# 129435       600.0  Instrumental - Ultraviolet Fluorescence API 10...
#
#           Local Site Name     Address     State Name  County Name  City Name
# 129074  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston  \
# 129075  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129076  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129077  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129078  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# ...                   ...         ...            ...          ...        ...
# 129431  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129432  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129433  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129434  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
# 129435  BOSTON KENMORE SQ  KENMORE SQ  Massachusetts      Suffolk     Boston
#
#                              CBSA Name  Date of Last Change
# 129074  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129075  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129076  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129077  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129078  Boston-Cambridge-Newton, MA-NH           2021-11-04
# ...                                ...                  ...
# 129431  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129432  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129433  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129434  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 129435  Boston-Cambridge-Newton, MA-NH           2021-11-04
#
# [362 rows x 29 columns]

# %%
traindata_CO_Lynn_2021 = traindata_CO_2021.loc[traindata_CO_2021["City Name"] == "Boston"]
traindata_CO_Lynn_2020 = traindata_CO_2020.loc[traindata_CO_2020["City Name"] == "Boston"]
traindata_CO_Lynn_2019 = traindata_CO_2019.loc[traindata_CO_2019["City Name"] == "Boston"]
traindata_CO_Lynn_2018 = traindata_CO_2018.loc[traindata_CO_2018["City Name"] == "Boston"]

# CO_mask2 = traindata_CO_Lynn_2018["Sample Duration"] == "1 HOUR"

traindata_CO_Lynn_2021 = traindata_CO_Lynn_2021.loc[traindata_CO_Lynn_2021["Sample Duration"] == "1 HOUR"]
traindata_CO_Lynn_2020 = traindata_CO_Lynn_2020.loc[traindata_CO_Lynn_2020["Sample Duration"] == "1 HOUR"]
traindata_CO_Lynn_2019 = traindata_CO_Lynn_2019.loc[traindata_CO_Lynn_2019["Sample Duration"] == "1 HOUR"]
traindata_CO_Lynn_2018 = traindata_CO_Lynn_2018.loc[traindata_CO_Lynn_2018["Sample Duration"] == "1 HOUR"]

traindata_CO_Lynn_2021 = traindata_CO_Lynn_2021.loc[traindata_CO_Lynn_2021["Address"] == "HARRISON AVE"]
traindata_CO_Lynn_2020 = traindata_CO_Lynn_2020.loc[traindata_CO_Lynn_2020["Address"] == "HARRISON AVE"]
traindata_CO_Lynn_2019 = traindata_CO_Lynn_2019.loc[traindata_CO_Lynn_2019["Address"] == "HARRISON AVE"]
traindata_CO_Lynn_2018 = traindata_CO_Lynn_2018.loc[traindata_CO_Lynn_2018["Address"] == "HARRISON AVE"]

# %%
traindata_CO_Lynn_2021
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC  Latitude
# 86507          25           25        42           42101    1   42.3295  \
# 86508          25           25        42           42101    1   42.3295
# 86509          25           25        42           42101    1   42.3295
# 86510          25           25        42           42101    1   42.3295
# 86511          25           25        42           42101    1   42.3295
# ...           ...          ...       ...             ...  ...       ...
# 86860          25           25        42           42101    1   42.3295
# 86861          25           25        42           42101    1   42.3295
# 86862          25           25        42           42101    1   42.3295
# 86863          25           25        42           42101    1   42.3295
# 86864          25           25        42           42101    1   42.3295
#
#        Longitude  Datum   Parameter Name Sample Duration  ... AQI Method Code
# 86507   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0  \
# 86508   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86509   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86510   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86511   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# ...          ...    ...              ...             ...  ...  ..         ...
# 86860   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86861   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86862   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86863   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
# 86864   -71.0826  WGS84  Carbon monoxide          1 HOUR  ... NaN       593.0
#
#                                              Method Name
# 86507  INSTRUMENTAL - Gas Filter Correlation Teledyne...  \
# 86508  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86509  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86510  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86511  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# ...                                                  ...
# 86860  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86861  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86862  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86863  INSTRUMENTAL - Gas Filter Correlation Teledyne...
# 86864  INSTRUMENTAL - Gas Filter Correlation Teledyne...
#
#              Local Site Name       Address     State Name  County Name
# 86507  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk  \
# 86508  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86509  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86510  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86511  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# ...                      ...           ...            ...          ...
# 86860  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86861  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86862  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86863  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
# 86864  DUDLEY SQUARE ROXBURY  HARRISON AVE  Massachusetts      Suffolk
#
#        City Name                       CBSA Name  Date of Last Change
# 86507     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86508     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86509     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86510     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86511     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# ...          ...                             ...                  ...
# 86860     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86861     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86862     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86863     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
# 86864     Boston  Boston-Cambridge-Newton, MA-NH           2022-03-24
#
# [358 rows x 29 columns]

# %%
traindata_NO2_Lynn_2021 = traindata_NO2_2021.loc[traindata_NO2_2021["City Name"] == "Lynn"]
traindata_NO2_Lynn_2020 = traindata_NO2_2020.loc[traindata_NO2_2020["City Name"] == "Lynn"]
traindata_NO2_Lynn_2019 = traindata_NO2_2019.loc[traindata_NO2_2019["City Name"] == "Lynn"]
traindata_NO2_Lynn_2018 = traindata_NO2_2018.loc[NO2_mask]

# %%
traindata_NO2_Lynn_2018
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 69768          25            9      2006           42602    1  42.474642  \
# 69769          25            9      2006           42602    1  42.474642
# 69770          25            9      2006           42602    1  42.474642
# 69771          25            9      2006           42602    1  42.474642
# 69772          25            9      2006           42602    1  42.474642
# ...           ...          ...       ...             ...  ...        ...
# 70127          25            9      2006           42602    1  42.474642
# 70128          25            9      2006           42602    1  42.474642
# 70129          25            9      2006           42602    1  42.474642
# 70130          25            9      2006           42602    1  42.474642
# 70131          25            9      2006           42602    1  42.474642
#
#        Longitude  Datum          Parameter Name Sample Duration  ... AQI
# 69768 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...   7  \
# 69769 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  19
# 69770 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  34
# 69771 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  30
# 69772 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...   2
# ...          ...    ...                     ...             ...  ...  ..
# 70127 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  16
# 70128 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  25
# 70129 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  21
# 70130 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  33
# 70131 -70.970816  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  28
#
#       Method Code                                 Method Name
# 69768          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE  \
# 69769          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 69770          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 69771          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 69772          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# ...           ...                                         ...
# 70127          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 70128          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 70129          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 70130          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
# 70131          99  INSTRUMENTAL - GAS PHASE CHEMILUMINESCENCE
#
#                   Local Site Name       Address     State Name  County Name
# 69768  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex  \
# 69769  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 69770  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 69771  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 69772  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# ...                           ...           ...            ...          ...
# 70127  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 70128  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 70129  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 70130  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
# 70131  LYNN WATER TREATMENT PLANT  390 PARKLAND  Massachusetts        Essex
#
#        City Name                       CBSA Name  Date of Last Change
# 69768       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 69769       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 69770       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 69771       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 69772       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# ...          ...                             ...                  ...
# 70127       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 70128       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 70129       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 70130       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
# 70131       Lynn  Boston-Cambridge-Newton, MA-NH           2021-11-04
#
# [364 rows x 29 columns]

# %%
# Dropping the unneeded cols

dropped_cols = ['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
       'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
       'Pollutant Standard', 'Units of Measure', 'Event Type',
       'Observation Count', 'Observation Percent', 
       '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
       'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
       'CBSA Name', 'Date of Last Change']

target_data_Lynn_2021 = target_data_Lynn_2021.drop(dropped_cols, axis=1)
target_data_Lynn_2020 = target_data_Lynn_2020.drop(dropped_cols, axis=1)
target_data_Lynn_2019 = target_data_Lynn_2019.drop(dropped_cols, axis=1)
target_data_Lynn_2018 = target_data_Lynn_2018.drop(dropped_cols, axis=1)

traindata_SO2_Lynn_2021 = traindata_SO2_Lynn_2021.drop(dropped_cols, axis=1)
traindata_SO2_Lynn_2020 = traindata_SO2_Lynn_2020.drop(dropped_cols, axis=1)
traindata_SO2_Lynn_2019 = traindata_SO2_Lynn_2019.drop(dropped_cols, axis=1)
traindata_SO2_Lynn_2018 = traindata_SO2_Lynn_2018.drop(dropped_cols, axis=1)

traindata_CO_Lynn_2021 = traindata_CO_Lynn_2021.drop(dropped_cols, axis=1)
traindata_CO_Lynn_2020 = traindata_CO_Lynn_2020.drop(dropped_cols, axis=1)
traindata_CO_Lynn_2019 = traindata_CO_Lynn_2019.drop(dropped_cols, axis=1)
traindata_CO_Lynn_2018 = traindata_CO_Lynn_2018.drop(dropped_cols, axis=1)

traindata_NO2_Lynn_2021 = traindata_NO2_Lynn_2021.drop(dropped_cols, axis=1)
traindata_NO2_Lynn_2020 = traindata_NO2_Lynn_2020.drop(dropped_cols, axis=1)
traindata_NO2_Lynn_2019 = traindata_NO2_Lynn_2019.drop(dropped_cols, axis=1)
traindata_NO2_Lynn_2018 = traindata_NO2_Lynn_2018.drop(dropped_cols, axis=1)

# %%
traindata_SO2_Lynn_2021
# Out:
#         Date Local  Arithmetic Mean
# 114582  2021-01-01        -0.323810
# 114583  2021-01-02        -0.279167
# 114584  2021-01-03        -0.275000
# 114585  2021-01-04        -0.214286
# 114586  2021-01-05        -0.279167
# ...            ...              ...
# 114942  2021-12-27        -0.057143
# 114943  2021-12-28         0.108333
# 114944  2021-12-29         0.050000
# 114945  2021-12-30         0.228571
# 114946  2021-12-31         0.233333
#
# [365 rows x 2 columns]

# %%
# Adding all 4 years into 1 dataset
target_data = pd.concat([target_data_Lynn_2018, target_data_Lynn_2019, target_data_Lynn_2020, target_data_Lynn_2021], ignore_index=True)
target_data = target_data.rename(columns={"Arithmetic Mean": "ozone"})


traindata_SO2 = pd.concat([traindata_SO2_Lynn_2018, traindata_SO2_Lynn_2019, traindata_SO2_Lynn_2020, traindata_SO2_Lynn_2021], ignore_index=True)
traindata_SO2 = traindata_SO2.rename(columns={"Arithmetic Mean": "SO2"})


traindata_CO = pd.concat([traindata_CO_Lynn_2018, traindata_CO_Lynn_2019, traindata_CO_Lynn_2020, traindata_CO_Lynn_2021], ignore_index=True)
traindata_CO = traindata_CO.rename(columns={"Arithmetic Mean": "CO"})


traindata_NO2 = pd.concat([traindata_NO2_Lynn_2018, traindata_NO2_Lynn_2019, traindata_NO2_Lynn_2020, traindata_NO2_Lynn_2021], ignore_index=True)
traindata_NO2 = traindata_NO2.rename(columns={"Arithmetic Mean": "NO2"})

# %%
# Reformating and renaming the DATE column in the main traindata set

target_data["Date Local"] = pd.to_datetime(target_data["Date Local"])
traindata_SO2["Date Local"] = pd.to_datetime(traindata_SO2["Date Local"])
traindata_CO["Date Local"] = pd.to_datetime(traindata_CO["Date Local"])
traindata_NO2["Date Local"] = pd.to_datetime(traindata_NO2["Date Local"])

traindata["DATE"] = pd.to_datetime(traindata["DATE"])
traindata = traindata.rename(columns={"DATE": "Date Local"})

# %%
# Merging all together
dataset = pd.merge(target_data, traindata, on='Date Local').merge(traindata_SO2, on="Date Local").merge(traindata_CO, on="Date Local").merge(traindata_NO2, on="Date Local")

# %%
# dataset["ozone"] = dataset["ozone"] * 1000
# dataset

# %%
dataset.isna().sum()
# Out:
# Date Local    0
# ozone         0
# STATION       0
# NAME          0
# LATITUDE      0
# LONGITUDE     0
# ELEVATION     0
# AWND          0
# PRCP          0
# TAVG          0
# TMAX          0
# TMIN          0
# SO2           0
# CO            0
# NO2           0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Date Local', 'ozone', 'STATION', 'NAME', 'LATITUDE', 'LONGITUDE',
#        'ELEVATION', 'AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'SO2', 'CO',
#        'NO2'],
#       dtype='object')

# %%
useless_cols = ['Date Local', 'STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION']

dataset = dataset.drop(useless_cols, axis=1)

# %%
dataset
# Out:
#          ozone  AWND  PRCP  TAVG  TMAX  TMIN       SO2        CO        NO2
# 0     0.038583   7.3   0.0 -14.7 -10.5 -17.7  0.762500  0.175435   0.875000
# 1     0.007917   4.2   0.0  -6.2  -1.6  -8.8  1.995833  0.348053  18.750000
# 2     0.036176  10.1  34.3  -3.6  -1.0  -5.5  1.495833  0.265957   8.333333
# 3     0.035941  11.1   0.0  -7.8  -4.3 -14.3  0.923810  0.184636   0.545455
# 4     0.036824   9.8   0.0 -13.1 -11.0 -17.1  0.741667  0.165783  -0.041667
# ...        ...   ...   ...   ...   ...   ...       ...       ...        ...
# 1607  0.038176   3.4   0.3  12.3  17.2   8.9  0.180952  0.311417   5.875000
# 1608  0.031706   5.2   0.0  16.7  24.4  10.6  0.245833  0.240684   3.845455
# 1609  0.037471   6.7   6.1  15.2  22.2   3.3  0.208333  0.194087   4.550000
# 1610  0.037235   9.0   0.0   5.3   8.3   1.1  0.166667  0.155955   1.175000
# 1611  0.045000   7.6   0.0   8.6  15.6   3.3  0.158333  0.174333   1.781818
#
# [1612 rows x 9 columns]

# %%
exceedance = 0
for i in range(len(dataset)):
    if dataset['ozone'][i] >= 0.075:
        exceedance += 1

print(exceedance)
# Out:
# 0

# %% [markdown]
# ## Segmenting the data into (train, valid, test)

# %%
# I want 95% for training purposes; 2.5% valid, 2.5% test

train, test = train_test_split(dataset, test_size=0.05, shuffle=False)

valid, test = train_test_split(test, test_size=.5, shuffle=False)

# %%
train.columns
# Out:
# Index(['ozone', 'AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'SO2', 'CO', 'NO2'], dtype='object')

# %%
# splitting into features and output

train_features = train.drop("ozone", axis=1)
train_output = train.drop(['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'SO2', 'CO', 'NO2'], axis=1)

valid_features = valid.drop("ozone", axis=1)
valid_output = valid.drop(['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'SO2', 'CO', 'NO2'], axis=1)

test_features = test.drop("ozone", axis=1)
test_output = test.drop(['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'SO2', 'CO', 'NO2'], axis=1)

# %%
# Scaling pre-processing
scaler = StandardScaler()
scaler.fit(train_features)

# Define Train Set
X_train = torch.from_numpy(scaler.transform(train_features.values)).float()
y_train = torch.from_numpy(train_output.values).float()
train_dataset = TensorDataset(X_train, y_train)

# Define Valid Set
X_valid = torch.from_numpy(scaler.transform(valid_features.values)).float()
y_valid = torch.from_numpy(valid_output.values).float()
valid_dataset = TensorDataset(X_valid, y_valid)


# Define Test Set
X_test = torch.from_numpy(scaler.transform(test_features.values)).float()
y_test = torch.from_numpy(test_output.values).float()
test_dataset = TensorDataset(X_test, y_test)

# Use Pytorch's functionality to load data in batches.
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False) # shape [batch_size=256, features=17, output=1]
valid_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
len(X_valid)
# Out:
# 40

# %% [markdown]
# ## Defining the neural network

# %%
# define 4 layer NN

class NeuralNetwork(torch.nn.Module):
     def __init__(self, input_size, hidden_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.linear1 = torch.nn.Linear(input_size, hidden_size)
        self.activation1 = torch.nn.LeakyReLU(negative_slope=0.1, inplace=False)
        self.dropout = nn.Dropout(p=0.5)
        self.linear2 = torch.nn.Linear(hidden_size, hidden_size//2)
        self.activation2 = torch.nn.LeakyReLU(negative_slope=0.1, inplace=False)
        self.linear3 = torch.nn.Linear(hidden_size//2, hidden_size//4)
        self.activation3 = torch.nn.LeakyReLU(negative_slope=0.1, inplace=False)
        self.linear4 = torch.nn.Linear(hidden_size//4, output_size)
        
     def forward(self, x):
        x=self.linear1(x)       #Order of operations (apply linear, apply activation, apply linear again, then return the tensor
        x=self.activation1(x)
        x=self.dropout(x)
        x=self.linear2(x)
        x=self.activation2(x)
        x=self.dropout(x)
        x=self.linear3(x)
        x=self.activation3(x)
        x=self.dropout(x)
        x=self.linear4(x)
        return x

# %%
# define 2 layer NN

class NeuralNetwork_Smol(torch.nn.Module):
     def __init__(self, input_size, hidden_size, output_size):
        super(NeuralNetwork_Smol, self).__init__()
        self.linear1 = torch.nn.Linear(input_size, hidden_size)
        self.activation1 = torch.nn.LeakyReLU(negative_slope=0.1, inplace=False)
        self.linear2 = torch.nn.Linear(hidden_size, output_size)
        
     def forward(self, x):
        x=self.linear1(x)       #Order of operations (apply linear, apply activation, apply linear again, then return the tensor
        x=self.activation1(x)
        x=self.linear2(x)
        return x

# %%
#train and optimization for small network

neural_model_smol=NeuralNetwork_Smol(input_size=8, hidden_size=64, output_size=1)  #empty model waiting for data
neural_model_smol.to(device)
criterion=torch.nn.MSELoss()      #Pulls class from Super.__init__ from torch.nn.Module
optimizer=torch.optim.Adam(neural_model_smol.parameters(), lr=0.001)    # adding L2 regulization strength of 0.01

best_loss = float('inf')

steps = []
Train_loss = []     #     FOR PLOTTING PURPOSES

for epoch in range(250):
    for data in train_loader:
        data[0] = data[0].to(device)
        data[1] = data[1].to(device)

        #forward 
        outputs=neural_model_smol(data[0])
        outputs = outputs.squeeze(1)
        # print(outputs, data[1].float())
        loss=criterion(outputs, data[1])   #comparing loss from output to target
    
        #backward and optimization 
        optimizer.zero_grad()   #ORder of opetations
        loss.backward()
        optimizer.step()
    steps.append(epoch)
    Train_loss.append(loss.cpu().detach().numpy().copy())                   #      FOR PLOTTING PURPOSES   loss.item?
    
    
    print("epoch {}, loss function {}".format(epoch, loss.item()))
    # a good MSE Loss is usually 1  Aka. 0.something
    # if loss.item() < best_loss:
    #     # save network
    #     torch.save(neural_model_smol.state_dict(), "best_model_Smol.pth")
    #     best_loss = loss.item()
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/torch/nn/modules/loss.py:530: UserWarning: Using a target size (torch.Size([32, 1])) that is different to the input size (torch.Size([32])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/torch/nn/modules/loss.py:530: UserWarning: Using a target size (torch.Size([27, 1])) that is different to the input size (torch.Size([27])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# epoch 0, loss function 0.004850286524742842
# epoch 1, loss function 0.0024050113279372454
# epoch 2, loss function 0.0021548846270889044
# epoch 3, loss function 0.0018484219908714294
# epoch 4, loss function 0.0016347269993275404
# epoch 5, loss function 0.0014513542409986258
# epoch 6, loss function 0.0013121957890689373
# epoch 7, loss function 0.001184798777103424
# epoch 8, loss function 0.0010812915861606598
# epoch 9, loss function 0.0009840552229434252
# epoch 10, loss function 0.0009066810016520321
# epoch 11, loss function 0.0008366003166884184
# epoch 12, loss function 0.0007796696154400706
# epoch 13, loss function 0.0007296606199815869
# epoch 14, loss function 0.0006850646459497511
# epoch 15, loss function 0.0006465455517172813
# epoch 16, loss function 0.0006148529937490821
# epoch 17, loss function 0.0005863705300725996
# epoch 18, loss function 0.0005628428771160543
# epoch 19, loss function 0.0005491710617206991
# epoch 20, loss function 0.0005305492668412626
# epoch 21, loss function 0.0005131483776494861
# epoch 22, loss function 0.0005190661759115756
# epoch 23, loss function 0.00049285200657323
# epoch 24, loss function 0.0004734910908155143
# epoch 25, loss function 0.0005266430671326816
# epoch 26, loss function 0.0004583508998621255
# epoch 27, loss function 0.0004234404768794775
# epoch 28, loss function 0.0006277888896875083
# epoch 29, loss function 0.0004440887423697859
# epoch 30, loss function 0.00034967370447702706
# epoch 31, loss function 0.0007299894350580871
# epoch 32, loss function 0.0006591637502424419
# epoch 33, loss function 0.000565942726098001
# epoch 34, loss function 0.0004245164745952934
# epoch 35, loss function 0.0003463036264292896
# epoch 36, loss function 0.0004294408718124032
# epoch 37, loss function 0.0003432341618463397
# epoch 38, loss function 0.00038428991683758795
# epoch 39, loss function 0.00035345423384569585
# epoch 40, loss function 0.0003564192447811365
# epoch 41, loss function 0.0003501288883853704
# epoch 42, loss function 0.00034103423240594566
# epoch 43, loss function 0.0003382299037184566
# epoch 44, loss function 0.0003342623240314424
# epoch 45, loss function 0.000328526075463742
# epoch 46, loss function 0.0003247427230235189
# epoch 47, loss function 0.00032376241870224476
# epoch 48, loss function 0.00031987871625460684
# epoch 49, loss function 0.00031551357824355364
# epoch 50, loss function 0.0003168406256008893
# epoch 51, loss function 0.0003180221829097718
# epoch 52, loss function 0.00030983294709585607
# epoch 53, loss function 0.00031056441366672516
# epoch 54, loss function 0.0003234094474464655
# epoch 55, loss function 0.00031725119333714247
# epoch 56, loss function 0.0003005862527061254
# epoch 57, loss function 0.0003273015609011054
# epoch 58, loss function 0.0003546868683770299
# epoch 59, loss function 0.00029803774668835104
# epoch 60, loss function 0.00029943668050691485
# epoch 61, loss function 0.00040614683530293405
# epoch 62, loss function 0.0003681991365738213
# epoch 63, loss function 0.0002485186269041151
# epoch 64, loss function 0.00033971513039432466
# epoch 65, loss function 0.0005714418366551399
# epoch 66, loss function 0.0002576473343651742
# epoch 67, loss function 0.0002595361729618162
# epoch 68, loss function 0.0003697770880535245
# epoch 69, loss function 0.00021517937420867383
# epoch 70, loss function 0.0003960579924751073
# epoch 71, loss function 0.0002765342069324106
# epoch 72, loss function 0.00027048788615502417
# epoch 73, loss function 0.00028523398214019835
# epoch 74, loss function 0.00028983893571421504
# epoch 75, loss function 0.0002887178852688521
# epoch 76, loss function 0.00029288005316630006
# epoch 77, loss function 0.0002952685463242233
# epoch 78, loss function 0.0002965525782201439
# epoch 79, loss function 0.00029816897585988045
# epoch 80, loss function 0.0002995501854456961
# epoch 81, loss function 0.00030065333703532815
# epoch 82, loss function 0.00030165325733833015
# epoch 83, loss function 0.0003027931961696595
# epoch 84, loss function 0.00030401398544199765
# epoch 85, loss function 0.000304893939755857
# epoch 86, loss function 0.00030571018578484654
# epoch 87, loss function 0.00030619572498835623
# epoch 88, loss function 0.00030748872086405754
# epoch 89, loss function 0.00030750673613511026
# epoch 90, loss function 0.0003082998446188867
# epoch 91, loss function 0.00030892217182554305
# epoch 92, loss function 0.000309308641590178
# epoch 93, loss function 0.0003098358865827322
# epoch 94, loss function 0.00030999211594462395
# epoch 95, loss function 0.0003112947742920369
# epoch 96, loss function 0.0003125152725260705
# epoch 97, loss function 0.0003124928043689579
# epoch 98, loss function 0.00031355893588624895
# epoch 99, loss function 0.0003149239346385002
# epoch 100, loss function 0.0003150913689751178
# epoch 101, loss function 0.0003145756490994245
# epoch 102, loss function 0.0003148185205645859
# epoch 103, loss function 0.00031785896862857044
# epoch 104, loss function 0.0003189619746990502
# epoch 105, loss function 0.00031601128284819424
# epoch 106, loss function 0.0003154290607199073
# epoch 107, loss function 0.00031813158420845866
# epoch 108, loss function 0.00031993683660402894
# epoch 109, loss function 0.0003156451275572181
# epoch 110, loss function 0.00030996775603853166
# epoch 111, loss function 0.0003146802191622555
# epoch 112, loss function 0.0003201672516297549
# epoch 113, loss function 0.00031082562054507434
# epoch 114, loss function 0.00029315860592760146
# epoch 115, loss function 0.00029970461037009954
# epoch 116, loss function 0.0002863561676349491
# epoch 117, loss function 0.0003122191410511732
# epoch 118, loss function 0.00039683227078057826
# epoch 119, loss function 0.0002534623199608177
# epoch 120, loss function 0.0002012506447499618
# epoch 121, loss function 0.00029913452453911304
# epoch 122, loss function 0.00022371558588929474
# epoch 123, loss function 0.0002314425219083205
# epoch 124, loss function 0.0002324100787518546
# epoch 125, loss function 0.00023131855414249003
# epoch 126, loss function 0.00023365713423117995
# epoch 127, loss function 0.00023550665355287492
# epoch 128, loss function 0.00023770894040353596
# epoch 129, loss function 0.00023984009749256074
# epoch 130, loss function 0.00024207500973716378
# epoch 131, loss function 0.00024424833827652037
# epoch 132, loss function 0.00024636430316604674
# epoch 133, loss function 0.0002483096031937748
# epoch 134, loss function 0.0002502427960280329
# epoch 135, loss function 0.00025221792748197913
# epoch 136, loss function 0.00025408316287212074
# epoch 137, loss function 0.00025567293050698936
# epoch 138, loss function 0.00025708909379318357
# epoch 139, loss function 0.0002585961774457246
# epoch 140, loss function 0.00025944094522856176
# epoch 141, loss function 0.00026025986880995333
# epoch 142, loss function 0.00026084293494932353
# epoch 143, loss function 0.00026103100390173495
# epoch 144, loss function 0.0002612940443214029
# epoch 145, loss function 0.00026151127531193197
# epoch 146, loss function 0.00026171631179749966
# epoch 147, loss function 0.0002614315308164805
# epoch 148, loss function 0.00026107969461008906
# epoch 149, loss function 0.0002605386544018984
# epoch 150, loss function 0.00025982112856581807
# epoch 151, loss function 0.00025927528622560203
# epoch 152, loss function 0.00025907944655045867
# epoch 153, loss function 0.00025879719760268927
# epoch 154, loss function 0.0002585837210062891
# epoch 155, loss function 0.0002579558058641851
# epoch 156, loss function 0.00025711386115290225
# epoch 157, loss function 0.0002561931614764035
# epoch 158, loss function 0.00025515948073007166
# epoch 159, loss function 0.0002540552231948823
# epoch 160, loss function 0.00025250602629967034
# epoch 161, loss function 0.00025113875744864345
# epoch 162, loss function 0.0002496544911991805
# epoch 163, loss function 0.00024837040109559894
# epoch 164, loss function 0.00024523743195459247
# epoch 165, loss function 0.00024335480702575296
# epoch 166, loss function 0.0002406915882602334
# epoch 167, loss function 0.0002375113108428195
# epoch 168, loss function 0.00023551304184366018
# epoch 169, loss function 0.00023223343305289745
# epoch 170, loss function 0.00023000042710918933
# epoch 171, loss function 0.00022635071945842355
# epoch 172, loss function 0.00022381861344911158
# epoch 173, loss function 0.0002207781799370423
# epoch 174, loss function 0.0002172905660700053
# epoch 175, loss function 0.00021454964007716626
# epoch 176, loss function 0.00021147768711671233
# epoch 177, loss function 0.000208725017728284
# epoch 178, loss function 0.00020681481692008674
# epoch 179, loss function 0.0002042370761046186
# epoch 180, loss function 0.00020210577349644154
# epoch 181, loss function 0.00020039232913404703
# epoch 182, loss function 0.00019760428403969854
# epoch 183, loss function 0.00019628532754722983
# epoch 184, loss function 0.00019393743423279375
# epoch 185, loss function 0.00019216911459807307
# epoch 186, loss function 0.00019029506074730307
# epoch 187, loss function 0.00018847250612452626
# epoch 188, loss function 0.00018727770657278597
# epoch 189, loss function 0.00018513247778173536
# epoch 190, loss function 0.00018498320423532277
# epoch 191, loss function 0.0001836660667322576
# epoch 192, loss function 0.00018261972581967711
# epoch 193, loss function 0.0001818640885176137
# epoch 194, loss function 0.00018068616918753833
# epoch 195, loss function 0.00017858497449196875
# epoch 196, loss function 0.00017776987806428224
# epoch 197, loss function 0.00017685527564026415
# epoch 198, loss function 0.00017539878899697214
# epoch 199, loss function 0.00017462947289459407
# epoch 200, loss function 0.00017355145246256143
# epoch 201, loss function 0.00017286835645791143
# epoch 202, loss function 0.00017161919095087796
# epoch 203, loss function 0.00017163591110147536
# epoch 204, loss function 0.00017068626766558737
# epoch 205, loss function 0.00016995216719806194
# epoch 206, loss function 0.00016891320410650223
# epoch 207, loss function 0.00016880231851246208
# epoch 208, loss function 0.00016785410116426647
# epoch 209, loss function 0.00016733811935409904
# epoch 210, loss function 0.0001667424221523106
# epoch 211, loss function 0.00016529092681594193
# epoch 212, loss function 0.00016543899255339056
# epoch 213, loss function 0.00016473843425046653
# epoch 214, loss function 0.00016367183707188815
# epoch 215, loss function 0.00016288485494442284
# epoch 216, loss function 0.00016121254884637892
# epoch 217, loss function 0.0001609611208550632
# epoch 218, loss function 0.00016026322555262595
# epoch 219, loss function 0.00015942407480906695
# epoch 220, loss function 0.00015856859681662172
# epoch 221, loss function 0.00015804331633262336
# epoch 222, loss function 0.00015736678324174136
# epoch 223, loss function 0.00015685375547036529
# epoch 224, loss function 0.00015611924754921347
# epoch 225, loss function 0.0001561127428431064
# epoch 226, loss function 0.00015555863501504064
# epoch 227, loss function 0.00015527250070590526
# epoch 228, loss function 0.00015405364683829248
# epoch 229, loss function 0.00015334112686105072
# epoch 230, loss function 0.00015337423246819526
# epoch 231, loss function 0.00015250424621626735
# epoch 232, loss function 0.00015204572991933674
# epoch 233, loss function 0.00015149421233218163
# epoch 234, loss function 0.00015084979531820863
# epoch 235, loss function 0.000150351770571433
# epoch 236, loss function 0.00014914928760845214
# epoch 237, loss function 0.0001491097646066919
# epoch 238, loss function 0.00014893671323079616
# epoch 239, loss function 0.00014739112521056086
# epoch 240, loss function 0.00014735189324710518
# epoch 241, loss function 0.00014742884377483279
# epoch 242, loss function 0.00014667015057057142
# epoch 243, loss function 0.00014632004604209214
# epoch 244, loss function 0.00014643567556049675
# epoch 245, loss function 0.00014587573241442442
# epoch 246, loss function 0.00014577562978956848
# epoch 247, loss function 0.00014523518620990217
# epoch 248, loss function 0.00014499298413284123
# epoch 249, loss function 0.00014520388504024595

# %%
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(Train_loss, 'k')
ax.set_xlabel("Epoch")
ax.set_ylabel("Train Loss")
# Out:
# Text(0, 0.5, 'Train Loss')

# %%
# Load the saved state dictionary
state_dict = torch.load('best_model_Smol.pth')

# Print the keys and shapes of the parameters in the state dictionary
for key, value in state_dict.items():
    print(key, value.shape)
# Out:
# linear1.weight torch.Size([32, 8])
# linear1.bias torch.Size([32])
# linear2.weight torch.Size([1, 32])
# linear2.bias torch.Size([1])

# %%
# Validation for smol
model = NeuralNetwork_Smol(input_size=8, hidden_size=64, output_size=1)
model.load_state_dict(torch.load('best_model_Smol.pth'))

# Define the loss function
criterion = nn.MSELoss()

# Initialize variables for tracking the validation loss
valid_losses = []

# Calculate the validation loss for each batch of validation data
with torch.no_grad():
    for batch_x, batch_y in valid_loader:
        y_pred = model(batch_x)
        loss = criterion(y_pred, batch_y)
        valid_losses.append(loss.item())

# Calculate the average validation loss
avg_valid_loss = np.mean(valid_losses)

y_true = y_valid

# %%
# Looking at the predictions vs true values for validation purposes

plt.figure(figsize=(13, 2))
plt.plot(y_true)
plt.plot(y_pred)

# %%
# Testing the model for smol

# Load saved model
model = NeuralNetwork_Smol(input_size=8, hidden_size=64, output_size=1)
model.load_state_dict(torch.load('best_model_Smol.pth'))


# Evaluate the model
model.eval()
y_preds = []
with torch.no_grad():
    for batch_x, batch_y in test_loader:
        y_pred = model(batch_x)
        y_preds.append(y_pred.numpy())

# Compute the evaluation metrics

y_pred = np.concatenate(y_preds, axis=0)
y_true = y_test

# %%
# Looking at the predictions vs true values for testing the model

plt.figure(figsize=(13, 2))
plt.plot(y_true)
plt.plot(y_pred)

# %%
testing_error_mse = mean_squared_error(y_true, y_pred)
print("MSE: ", testing_error_mse)
# Out:
# MSE:  5.23122e-05

# %% [markdown]
# ## Predicting Ozone pollution in different cities

# %%
# Importing the main meteorological data

pr_temp_wind = pd.read_csv('./Data/Jacksonville.csv', sep=',')

# %%
pr_temp_wind = pr_temp_wind.dropna()
pr_temp_wind
# Out:
#           STATION        DATE  AWND  PRCP  TAVG  TMAX  TMIN
# 0     USW00013889  2018-01-01   6.4   4.1   5.6   8.3   2.2
# 1     USW00013889  2018-01-02   6.6   0.0   1.9   5.0  -0.5
# 2     USW00013889  2018-01-03   4.8  20.6   2.1   5.0  -1.0
# 3     USW00013889  2018-01-04   4.7   0.0   2.0   8.3  -2.1
# 4     USW00013889  2018-01-05   2.6   0.0   2.5   9.4  -2.1
# ...           ...         ...   ...   ...   ...   ...   ...
# 1456  USW00013889  2021-12-27   2.6   0.0  17.7  24.4  13.9
# 1457  USW00013889  2021-12-28   1.3   0.0  17.6  26.7  11.7
# 1458  USW00013889  2021-12-29   3.2   0.0  18.6  27.8  11.7
# 1459  USW00013889  2021-12-30   3.2   0.0  20.9  27.8  15.0
# 1460  USW00013889  2021-12-31   3.4   0.0  23.0  28.3  19.4
#
# [1461 rows x 7 columns]

# %% [markdown]
# https://www.ncei.noaa.gov/access/search/data-search/daily-summaries?bbox=30.883,-98.852,29.529,-96.526&startDate=2018-01-01T00:00:00&endDate=2021-12-31T23:59:59&dataTypes=AWND&dataTypes=PRCP&dataTypes=TAVG&dataTypes=TMAX&dataTypes=TMIN
#
#
# No Average temperature

# %%
target_data_Florida_2021 = target_data_2021.loc[target_data_2021["City Name"] == "Jacksonville"]
target_data_Florida_2020 = target_data_2020.loc[target_data_2020["City Name"] == "Jacksonville"]
target_data_Florida_2019 = target_data_2019.loc[target_data_2019["City Name"] == "Jacksonville"]
target_data_Florida_2018 = target_data_2018.loc[target_data_2018["City Name"] == "Jacksonville"]

# %%
target_data_Florida_2018
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 112049          12           31        77           44201    1  30.477725  \
# 112050          12           31        77           44201    1  30.477725
# 112051          12           31        77           44201    1  30.477725
# 112052          12           31        77           44201    1  30.477725
# 112053          12           31        77           44201    1  30.477725
# ...            ...          ...       ...             ...  ...        ...
# 113131          12           31       106           44201    1  30.378217
# 113132          12           31       106           44201    1  30.378217
# 113133          12           31       106           44201    1  30.378217
# 113134          12           31       106           44201    1  30.378217
# 113135          12           31       106           44201    1  30.378217
#
#         Longitude  Datum Parameter Name          Sample Duration  ... AQI
# 112049 -81.587339  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  29  \
# 112050 -81.587339  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  30
# 112051 -81.587339  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  27
# 112052 -81.587339  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31
# 112053 -81.587339  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  19
# ...           ...    ...            ...                      ...  ...  ..
# 113131 -81.840900  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31
# 113132 -81.840900  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  23
# 113133 -81.840900  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  15
# 113134 -81.840900  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  20
# 113135 -81.840900  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  27
#
#        Method Code Method Name Local Site Name           Address  State Name
# 112049         NaN          -        Sheffield  13333 LANIER RD.     Florida  \
# 112050         NaN          -        Sheffield  13333 LANIER RD.     Florida
# 112051         NaN          -        Sheffield  13333 LANIER RD.     Florida
# 112052         NaN          -        Sheffield  13333 LANIER RD.     Florida
# 112053         NaN          -        Sheffield  13333 LANIER RD.     Florida
# ...            ...         ...             ...               ...         ...
# 113131         NaN          -      Cisco Drive     4770 Cisco Dr     Florida
# 113132         NaN          -      Cisco Drive     4770 Cisco Dr     Florida
# 113133         NaN          -      Cisco Drive     4770 Cisco Dr     Florida
# 113134         NaN          -      Cisco Drive     4770 Cisco Dr     Florida
# 113135         NaN          -      Cisco Drive     4770 Cisco Dr     Florida
#
#         County Name     City Name         CBSA Name  Date of Last Change
# 112049        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112050        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112051        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112052        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112053        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# ...             ...           ...               ...                  ...
# 113131        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113132        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113133        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113134        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113135        Duval  Jacksonville  Jacksonville, FL           2021-11-03
#
# [1087 rows x 29 columns]

# %%
target_data_Florida_2021 = target_data_Florida_2021.loc[target_data_2021["Local Site Name"] == "Cisco Drive"]
target_data_Florida_2020 = target_data_Florida_2020.loc[target_data_2020["Local Site Name"] == "Cisco Drive"]
target_data_Florida_2019 = target_data_Florida_2019.loc[target_data_2019["Local Site Name"] == "Cisco Drive"]
target_data_Florida_2018 = target_data_Florida_2018.loc[target_data_2018["Local Site Name"] == "Cisco Drive"]

# %%
target_data_Florida_2018
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 112771          12           31       106           44201    1  30.378217  \
# 112772          12           31       106           44201    1  30.378217
# 112773          12           31       106           44201    1  30.378217
# 112774          12           31       106           44201    1  30.378217
# 112775          12           31       106           44201    1  30.378217
# ...            ...          ...       ...             ...  ...        ...
# 113131          12           31       106           44201    1  30.378217
# 113132          12           31       106           44201    1  30.378217
# 113133          12           31       106           44201    1  30.378217
# 113134          12           31       106           44201    1  30.378217
# 113135          12           31       106           44201    1  30.378217
#
#         Longitude  Datum Parameter Name          Sample Duration  ... AQI
# 112771   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31  \
# 112772   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  33
# 112773   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31
# 112774   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  36
# 112775   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  34
# ...           ...    ...            ...                      ...  ...  ..
# 113131   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31
# 113132   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  23
# 113133   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  15
# 113134   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  20
# 113135   -81.8409  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  27
#
#        Method Code Method Name Local Site Name        Address  State Name
# 112771         NaN          -      Cisco Drive  4770 Cisco Dr     Florida  \
# 112772         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 112773         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 112774         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 112775         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# ...            ...         ...             ...            ...         ...
# 113131         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 113132         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 113133         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 113134         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
# 113135         NaN          -      Cisco Drive  4770 Cisco Dr     Florida
#
#         County Name     City Name         CBSA Name  Date of Last Change
# 112771        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112772        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112773        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112774        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 112775        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# ...             ...           ...               ...                  ...
# 113131        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113132        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113133        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113134        Duval  Jacksonville  Jacksonville, FL           2021-11-03
# 113135        Duval  Jacksonville  Jacksonville, FL           2021-11-03
#
# [365 rows x 29 columns]

# %%
traindata_SO2_Florida_2021 = traindata_SO2_2021.loc[traindata_SO2_2021["City Name"] == "Jacksonville"]
traindata_SO2_Florida_2020 = traindata_SO2_2020.loc[traindata_SO2_2020["City Name"] == "Jacksonville"]
traindata_SO2_Florida_2019 = traindata_SO2_2019.loc[traindata_SO2_2019["City Name"] == "Jacksonville"]
traindata_SO2_Florida_2018 = traindata_SO2_2018.loc[traindata_SO2_2018["City Name"] == "Jacksonville"]

traindata_SO2_Florida_2021 = traindata_SO2_Florida_2021.loc[traindata_SO2_Florida_2021["Sample Duration"] == "1 HOUR"]
traindata_SO2_Florida_2020 = traindata_SO2_Florida_2020.loc[traindata_SO2_Florida_2020["Sample Duration"] == "1 HOUR"]
traindata_SO2_Florida_2019 = traindata_SO2_Florida_2019.loc[traindata_SO2_Florida_2019["Sample Duration"] == "1 HOUR"]
traindata_SO2_Florida_2018 = traindata_SO2_Florida_2018.loc[traindata_SO2_Florida_2018["Sample Duration"] == "1 HOUR"]


traindata_SO2_Florida_2021 = traindata_SO2_Florida_2021.loc[traindata_SO2_Florida_2021["Local Site Name"] == "Kooker Park"]
traindata_SO2_Florida_2020 = traindata_SO2_Florida_2020.loc[traindata_SO2_Florida_2020["Local Site Name"] == "Kooker Park"]
traindata_SO2_Florida_2019 = traindata_SO2_Florida_2019.loc[traindata_SO2_Florida_2019["Local Site Name"] == "Kooker Park"]
traindata_SO2_Florida_2018 = traindata_SO2_Florida_2018.loc[traindata_SO2_Florida_2018["Local Site Name"] == "Kooker Park"]

traindata_SO2_Florida_2021
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 40379          12           31        32           42401    1  30.356339  \
# 40380          12           31        32           42401    1  30.356339
# 40381          12           31        32           42401    1  30.356339
# 40382          12           31        32           42401    1  30.356339
# 40383          12           31        32           42401    1  30.356339
# ...           ...          ...       ...             ...  ...        ...
# 40739          12           31        32           42401    1  30.356339
# 40740          12           31        32           42401    1  30.356339
# 40741          12           31        32           42401    1  30.356339
# 40742          12           31        32           42401    1  30.356339
# 40743          12           31        32           42401    1  30.356339
#
#        Longitude  Datum  Parameter Name Sample Duration  ...  AQI Method Code
# 40379 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  3.0        60.0  \
# 40380 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
# 40381 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
# 40382 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
# 40383 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  3.0        60.0
# ...          ...    ...             ...             ...  ...  ...         ...
# 40739 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  3.0        60.0
# 40740 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
# 40741 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
# 40742 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
# 40743 -81.635396  WGS84  Sulfur dioxide          1 HOUR  ...  1.0        60.0
#
#                              Method Name Local Site Name
# 40379  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park  \
# 40380  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40381  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40382  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40383  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# ...                                  ...             ...
# 40739  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40740  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40741  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40742  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
# 40743  INSTRUMENTAL - PULSED FLUORESCENT     Kooker Park
#
#                                            Address  State Name  County Name
# 40379  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval  \
# 40380  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40381  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40382  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40383  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# ...                                            ...         ...          ...
# 40739  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40740  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40741  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40742  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
# 40743  2900 Bennett Street, Jacksonville, FL 32206     Florida        Duval
#
#           City Name         CBSA Name  Date of Last Change
# 40379  Jacksonville  Jacksonville, FL           2022-03-04
# 40380  Jacksonville  Jacksonville, FL           2022-03-04
# 40381  Jacksonville  Jacksonville, FL           2022-03-04
# 40382  Jacksonville  Jacksonville, FL           2022-03-04
# 40383  Jacksonville  Jacksonville, FL           2022-03-04
# ...             ...               ...                  ...
# 40739  Jacksonville  Jacksonville, FL           2022-03-04
# 40740  Jacksonville  Jacksonville, FL           2022-03-04
# 40741  Jacksonville  Jacksonville, FL           2022-03-04
# 40742  Jacksonville  Jacksonville, FL           2022-03-04
# 40743  Jacksonville  Jacksonville, FL           2022-03-04
#
# [365 rows x 29 columns]

# %%
traindata_CO_Florida_2021 = traindata_CO_2021.loc[traindata_CO_2021["City Name"] == "Jacksonville"]
traindata_CO_Florida_2020 = traindata_CO_2020.loc[traindata_CO_2020["City Name"] == "Jacksonville"]
traindata_CO_Florida_2019 = traindata_CO_2019.loc[traindata_CO_2019["City Name"] == "Jacksonville"]
traindata_CO_Florida_2018 = traindata_CO_2018.loc[traindata_CO_2018["City Name"] == "Jacksonville"]

traindata_CO_Florida_2021 = traindata_CO_Florida_2021.loc[traindata_CO_Florida_2021["Sample Duration"] == "1 HOUR"]
traindata_CO_Florida_2020 = traindata_CO_Florida_2020.loc[traindata_CO_Florida_2020["Sample Duration"] == "1 HOUR"]
traindata_CO_Florida_2019 = traindata_CO_Florida_2019.loc[traindata_CO_Florida_2019["Sample Duration"] == "1 HOUR"]
traindata_CO_Florida_2018 = traindata_CO_Florida_2018.loc[traindata_CO_Florida_2018["Sample Duration"] == "1 HOUR"]

traindata_CO_Florida_2021 = traindata_CO_Florida_2021.loc[traindata_CO_Florida_2021["Local Site Name"] == "Pepsi Place"]
traindata_CO_Florida_2020 = traindata_CO_Florida_2020.loc[traindata_CO_Florida_2020["Local Site Name"] == "Pepsi Place"]
traindata_CO_Florida_2019 = traindata_CO_Florida_2019.loc[traindata_CO_Florida_2019["Local Site Name"] == "Pepsi Place"]
traindata_CO_Florida_2018 = traindata_CO_Florida_2018.loc[traindata_CO_Florida_2018["Local Site Name"] == "Pepsi Place"]

traindata_CO_Florida_2021
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 63754          12           31       108           42101    1  30.262778  \
# 63755          12           31       108           42101    1  30.262778
# 63756          12           31       108           42101    1  30.262778
# 63757          12           31       108           42101    1  30.262778
# 63758          12           31       108           42101    1  30.262778
# ...           ...          ...       ...             ...  ...        ...
# 64114          12           31       108           42101    1  30.262778
# 64115          12           31       108           42101    1  30.262778
# 64116          12           31       108           42101    1  30.262778
# 64117          12           31       108           42101    1  30.262778
# 64118          12           31       108           42101    1  30.262778
#
#        Longitude  Datum   Parameter Name Sample Duration  ... AQI Method Code
# 63754 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0  \
# 63755 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 63756 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 63757 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 63758 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# ...          ...    ...              ...             ...  ...  ..         ...
# 64114 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 64115 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 64116 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 64117 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
# 64118 -81.606833  WGS84  Carbon monoxide          1 HOUR  ... NaN        54.0
#
#                                  Method Name Local Site Name
# 63754  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place  \
# 63755  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 63756  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 63757  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 63758  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# ...                                      ...             ...
# 64114  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 64115  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 64116  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 64117  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
# 64118  INSTRUMENTAL - NONDISPERSIVE INFRARED     Pepsi Place
#
#                                         Address  State Name  County Name
# 63754  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval  \
# 63755  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 63756  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 63757  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 63758  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# ...                                         ...         ...          ...
# 64114  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 64115  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 64116  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 64117  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
# 64118  5895 Pepsi Place, Jacksonville, FL 32216     Florida        Duval
#
#           City Name         CBSA Name  Date of Last Change
# 63754  Jacksonville  Jacksonville, FL           2022-03-04
# 63755  Jacksonville  Jacksonville, FL           2022-03-04
# 63756  Jacksonville  Jacksonville, FL           2022-03-04
# 63757  Jacksonville  Jacksonville, FL           2022-03-04
# 63758  Jacksonville  Jacksonville, FL           2022-03-04
# ...             ...               ...                  ...
# 64114  Jacksonville  Jacksonville, FL           2022-03-04
# 64115  Jacksonville  Jacksonville, FL           2022-03-04
# 64116  Jacksonville  Jacksonville, FL           2022-03-04
# 64117  Jacksonville  Jacksonville, FL           2022-03-04
# 64118  Jacksonville  Jacksonville, FL           2022-03-04
#
# [365 rows x 29 columns]

# %%
traindata_NO2_Florida_2021 = traindata_NO2_2021.loc[traindata_NO2_2021["City Name"] == "Jacksonville"]
traindata_NO2_Florida_2020 = traindata_NO2_2020.loc[traindata_NO2_2020["City Name"] == "Jacksonville"]
traindata_NO2_Florida_2019 = traindata_NO2_2019.loc[traindata_NO2_2019["City Name"] == "Jacksonville"]
traindata_NO2_Florida_2018 = traindata_NO2_2018.loc[traindata_NO2_2019["City Name"] == "Jacksonville"]

traindata_NO2_Florida_2021 = traindata_NO2_Florida_2021.loc[traindata_NO2_Florida_2021["Local Site Name"] == "Kooker Park"]
traindata_NO2_Florida_2020 = traindata_NO2_Florida_2020.loc[traindata_NO2_Florida_2020["Local Site Name"] == "Kooker Park"]
traindata_NO2_Florida_2019 = traindata_NO2_Florida_2019.loc[traindata_NO2_Florida_2019["Local Site Name"] == "Kooker Park"]
traindata_NO2_Florida_2018 = traindata_NO2_Florida_2018.loc[traindata_NO2_Florida_2018["Address"] == "7000 N. Ocean Drive, Dania, FL 33004"]

# %%
traindata_NO2_Florida_2018
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude
# 48832          12           11      8002           42602    1  26.087567  \
# 48833          12           11      8002           42602    1  26.087567
# 48834          12           11      8002           42602    1  26.087567
# 48835          12           11      8002           42602    1  26.087567
# 48836          12           11      8002           42602    1  26.087567
# 48837          12           11      8002           42602    1  26.087567
# 48838          12           11      8002           42602    1  26.087567
# 48839          12           11      8002           42602    1  26.087567
# 48840          12           11      8002           42602    1  26.087567
# 48841          12           11      8002           42602    1  26.087567
# 48842          12           11      8002           42602    1  26.087567
# 48843          12           11      8002           42602    1  26.087567
# 48844          12           11      8002           42602    1  26.087567
# 48845          12           11      8002           42602    1  26.087567
# 48846          12           11      8002           42602    1  26.087567
# 48847          12           11      8002           42602    1  26.087567
# 48848          12           11      8002           42602    1  26.087567
# 48849          12           11      8002           42602    1  26.087567
# 48850          12           11      8002           42602    1  26.087567
#
#        Longitude  Datum          Parameter Name Sample Duration  ... AQI
# 48832 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  30  \
# 48833 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  14
# 48834 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  24
# 48835 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  36
# 48836 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  22
# 48837 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  17
# 48838 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  15
# 48839 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...   2
# 48840 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  19
# 48841 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  31
# 48842 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...   1
# 48843 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  17
# 48844 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  31
# 48845 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  19
# 48846 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  29
# 48847 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  27
# 48848 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  20
# 48849 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  15
# 48850 -80.111152  NAD83  Nitrogen dioxide (NO2)          1 HOUR  ...  25
#
#       Method Code                       Method Name
# 48832          74  INSTRUMENTAL - CHEMILUMINESCENCE  \
# 48833          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48834          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48835          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48836          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48837          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48838          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48839          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48840          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48841          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48842          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48843          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48844          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48845          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48846          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48847          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48848          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48849          74  INSTRUMENTAL - CHEMILUMINESCENCE
# 48850          74  INSTRUMENTAL - CHEMILUMINESCENCE
#
#                                          Local Site Name
# 48832  Dr. Von Mizell-Eula Johnson State Park (prev. ...  \
# 48833  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48834  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48835  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48836  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48837  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48838  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48839  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48840  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48841  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48842  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48843  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48844  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48845  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48846  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48847  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48848  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48849  Dr. Von Mizell-Eula Johnson State Park (prev. ...
# 48850  Dr. Von Mizell-Eula Johnson State Park (prev. ...
#
#                                     Address  State Name  County Name
# 48832  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward  \
# 48833  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48834  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48835  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48836  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48837  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48838  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48839  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48840  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48841  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48842  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48843  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48844  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48845  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48846  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48847  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48848  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48849  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
# 48850  7000 N. Ocean Drive, Dania, FL 33004     Florida      Broward
#
#        City Name                                  CBSA Name
# 48832  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL  \
# 48833  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48834  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48835  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48836  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48837  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48838  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48839  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48840  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48841  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48842  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48843  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48844  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48845  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48846  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48847  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48848  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48849  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
# 48850  Hollywood  Miami-Fort Lauderdale-West Palm Beach, FL
#
#        Date of Last Change
# 48832           2021-11-03
# 48833           2021-11-03
# 48834           2021-11-03
# 48835           2021-11-03
# 48836           2021-11-03
# 48837           2021-11-03
# 48838           2021-11-03
# 48839           2021-11-03
# 48840           2021-11-03
# 48841           2021-11-03
# 48842           2021-11-03
# 48843           2021-11-03
# 48844           2021-11-03
# 48845           2021-11-03
# 48846           2021-11-03
# 48847           2021-11-03
# 48848           2021-11-03
# 48849           2021-11-03
# 48850           2021-11-03
#
# [19 rows x 29 columns]

# %%
#Dropping unneeded columns

target_data_Florida_2021 = target_data_Florida_2021.drop(dropped_cols, axis=1)
target_data_Florida_2020 = target_data_Florida_2020.drop(dropped_cols, axis=1)
target_data_Florida_2019 = target_data_Florida_2019.drop(dropped_cols, axis=1)
target_data_Florida_2018 = target_data_Florida_2018.drop(dropped_cols, axis=1)

traindata_SO2_Florida_2021 = traindata_SO2_Florida_2021.drop(dropped_cols, axis=1)
traindata_SO2_Florida_2020 = traindata_SO2_Florida_2020.drop(dropped_cols, axis=1)
traindata_SO2_Florida_2019 = traindata_SO2_Florida_2019.drop(dropped_cols, axis=1)
traindata_SO2_Florida_2018 = traindata_SO2_Florida_2018.drop(dropped_cols, axis=1)

traindata_CO_Florida_2021 = traindata_CO_Florida_2021.drop(dropped_cols, axis=1)
traindata_CO_Florida_2020 = traindata_CO_Florida_2020.drop(dropped_cols, axis=1)
traindata_CO_Florida_2019 = traindata_CO_Florida_2019.drop(dropped_cols, axis=1)
traindata_CO_Florida_2018 = traindata_CO_Florida_2018.drop(dropped_cols, axis=1)

traindata_NO2_Florida_2021 = traindata_NO2_Florida_2021.drop(dropped_cols, axis=1)
traindata_NO2_Florida_2020 = traindata_NO2_Florida_2020.drop(dropped_cols, axis=1)
traindata_NO2_Florida_2019 = traindata_NO2_Florida_2019.drop(dropped_cols, axis=1)
traindata_NO2_Florida_2018 = traindata_NO2_Florida_2018.drop(dropped_cols, axis=1)

# %%
target_data_Florida_2021
# Out:
#         Date Local  Arithmetic Mean
# 106671  2021-01-01         0.021235
# 106672  2021-01-02         0.021529
# 106673  2021-01-03         0.022235
# 106674  2021-01-04         0.018529
# 106675  2021-01-05         0.028706
# ...            ...              ...
# 107031  2021-12-27         0.015765
# 107032  2021-12-28         0.013941
# 107033  2021-12-29         0.026471
# 107034  2021-12-30         0.022824
# 107035  2021-12-31         0.020250
#
# [365 rows x 2 columns]

# %%
# Adding all 4 years into 1 dataset
True_Ozone_Florida = pd.concat([target_data_Florida_2018, target_data_Florida_2019, target_data_Florida_2020, target_data_Florida_2021], ignore_index=True)
True_Ozone_Florida = True_Ozone_Florida.rename(columns={"Arithmetic Mean": "ozone"})


Features_Florida_SO2 = pd.concat([traindata_SO2_Florida_2018, traindata_SO2_Florida_2019, traindata_SO2_Florida_2020, traindata_SO2_Florida_2021], ignore_index=True)
Features_Florida_SO2 = Features_Florida_SO2.rename(columns={"Arithmetic Mean": "SO2"})


Features_Florida_CO = pd.concat([traindata_CO_Florida_2018, traindata_CO_Florida_2019, traindata_CO_Florida_2020, traindata_CO_Florida_2021], ignore_index=True)
Features_Florida_CO = Features_Florida_CO.rename(columns={"Arithmetic Mean": "CO"})


Features_Florida_NO2 = pd.concat([traindata_NO2_Florida_2018, traindata_NO2_Florida_2019, traindata_NO2_Florida_2020, traindata_NO2_Florida_2021], ignore_index=True)
Features_Florida_NO2 = Features_Florida_NO2.rename(columns={"Arithmetic Mean": "NO2"})

# %%
Features_Florida_SO2
# Out:
#       Date Local       SO2
# 0     2018-01-01  0.141667
# 1     2018-01-02  0.170833
# 2     2018-01-03  0.111765
# 3     2018-01-04  0.273913
# 4     2018-01-05  2.062500
# ...          ...       ...
# 1447  2021-12-27  0.683333
# 1448  2021-12-28  0.529167
# 1449  2021-12-29  0.662500
# 1450  2021-12-30  0.575000
# 1451  2021-12-31  0.508333
#
# [1452 rows x 2 columns]

# %%
# Reformating and renaming the DATE column in the main traindata set

True_Ozone_Florida["Date Local"] = pd.to_datetime(True_Ozone_Florida["Date Local"])
Features_Florida_SO2["Date Local"] = pd.to_datetime(Features_Florida_SO2["Date Local"])
Features_Florida_CO["Date Local"] = pd.to_datetime(Features_Florida_CO["Date Local"])
Features_Florida_NO2["Date Local"] = pd.to_datetime(Features_Florida_NO2["Date Local"])

pr_temp_wind["DATE"] = pd.to_datetime(pr_temp_wind["DATE"])
pr_temp_wind = pr_temp_wind.rename(columns={"DATE": "Date Local"})

# %%
# Merging all together
dataset_Florida = pd.merge(True_Ozone_Florida, pr_temp_wind, on='Date Local').merge(Features_Florida_SO2, on="Date Local").merge(Features_Florida_CO, on="Date Local").merge(Features_Florida_NO2, on="Date Local")

# %%
dataset_Florida
# Out:
#      Date Local     ozone      STATION  AWND  PRCP  TAVG  TMAX  TMIN
# 0    2018-01-01  0.030000  USW00013889   6.4   4.1   5.6   8.3   2.2  \
# 1    2018-01-02  0.033706  USW00013889   6.6   0.0   1.9   5.0  -0.5
# 2    2018-01-03  0.030941  USW00013889   4.8  20.6   2.1   5.0  -1.0
# 3    2018-01-04  0.033846  USW00013889   4.7   0.0   2.0   8.3  -2.1
# 4    2018-01-05  0.023235  USW00013889   2.6   0.0   2.5   9.4  -2.1
# ...         ...       ...          ...   ...   ...   ...   ...   ...
# 1075 2021-12-27  0.015765  USW00013889   2.6   0.0  17.7  24.4  13.9
# 1076 2021-12-28  0.013941  USW00013889   1.3   0.0  17.6  26.7  11.7
# 1077 2021-12-29  0.026471  USW00013889   3.2   0.0  18.6  27.8  11.7
# 1078 2021-12-30  0.022824  USW00013889   3.2   0.0  20.9  27.8  15.0
# 1079 2021-12-31  0.020250  USW00013889   3.4   0.0  23.0  28.3  19.4
#
#            SO2        CO        NO2
# 0     0.141667  0.333333  18.209091
# 1     0.170833  0.355000   6.558333
# 2     0.111765  0.445455  14.838462
# 3     0.273913  0.495833  19.507692
# 4     2.062500  0.600000  10.891667
# ...        ...       ...        ...
# 1075  0.683333  0.591667  10.183333
# 1076  0.529167  0.604167   7.487500
# 1077  0.662500  0.641667   9.161111
# 1078  0.575000  0.575000   5.379167
# 1079  0.508333  0.562500   3.633333
#
# [1080 rows x 11 columns]

# %%
dataset_Florida = dataset_Florida.drop(["Date Local", "STATION"], axis=1)

# %%
dataset_Florida
# Out:
#          ozone  AWND  PRCP  TAVG  TMAX  TMIN       SO2        CO        NO2
# 0     0.030000   6.4   4.1   5.6   8.3   2.2  0.141667  0.333333  18.209091
# 1     0.033706   6.6   0.0   1.9   5.0  -0.5  0.170833  0.355000   6.558333
# 2     0.030941   4.8  20.6   2.1   5.0  -1.0  0.111765  0.445455  14.838462
# 3     0.033846   4.7   0.0   2.0   8.3  -2.1  0.273913  0.495833  19.507692
# 4     0.023235   2.6   0.0   2.5   9.4  -2.1  2.062500  0.600000  10.891667
# ...        ...   ...   ...   ...   ...   ...       ...       ...        ...
# 1075  0.015765   2.6   0.0  17.7  24.4  13.9  0.683333  0.591667  10.183333
# 1076  0.013941   1.3   0.0  17.6  26.7  11.7  0.529167  0.604167   7.487500
# 1077  0.026471   3.2   0.0  18.6  27.8  11.7  0.662500  0.641667   9.161111
# 1078  0.022824   3.2   0.0  20.9  27.8  15.0  0.575000  0.575000   5.379167
# 1079  0.020250   3.4   0.0  23.0  28.3  19.4  0.508333  0.562500   3.633333
#
# [1080 rows x 9 columns]

# %%
# splitting into features and output

Florida_Features = dataset_Florida.drop("ozone", axis=1)
Florida_True_Ozone = dataset_Florida.drop(['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'SO2', 'CO', 'NO2'], axis=1)

# %%
Florida_True_Ozone
# Out:
#          ozone
# 0     0.030000
# 1     0.033706
# 2     0.030941
# 3     0.033846
# 4     0.023235
# ...        ...
# 1075  0.015765
# 1076  0.013941
# 1077  0.026471
# 1078  0.022824
# 1079  0.020250
#
# [1080 rows x 1 columns]

# %%
# Define Train Set
X_Florida = torch.from_numpy(scaler.transform(Florida_Features.values)).float()
y_Florida = torch.from_numpy(Florida_True_Ozone.values).float()
Florida_Dataset = TensorDataset(X_Florida, y_Florida)

# Use Pytorch's functionality to load data in batches.
Florida_loader = DataLoader(Florida_Dataset, batch_size=32, shuffle=False)
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Predicting for Florida

# Load saved model
model = NeuralNetwork_Smol(input_size=8, hidden_size=64, output_size=1)
model.load_state_dict(torch.load('best_model_Smol.pth'))


# Evaluate the model
model.eval()
y_preds = []
with torch.no_grad():
    for batch_x, batch_y in Florida_loader:
        y_pred = model(batch_x)
        y_preds.append(y_pred.numpy())

# Compute the evaluation metrics

y_pred = np.concatenate(y_preds, axis=0)
y_true = y_Florida

# %%
# Looking at the predictions vs true values for testing the model

plt.figure(figsize=(13, 2))
plt.plot(y_true, label='True Values')
plt.plot(y_pred, label='Predicted Values')
plt.legend(loc='upper right')

# %%
testing_error_mse_Florida = mean_squared_error(y_true, y_pred)
print("MSE: ", testing_error_mse_Florida)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 testing_error_mse_Florida = mean_squared_error(y_true, y_pred)
#       2 print("MSE: ", testing_error_mse_Florida)
#
# NameError: name 'mean_squared_error' is not defined
